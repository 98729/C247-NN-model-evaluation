# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install keras

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,LSTM,BatchNormalization,MaxPooling2D,Reshape
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    # print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    # print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    # print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

# %%
## Loading the dataset
X_test = np.load("/content/drive/MyDrive/project/X_test.npy")
y_test = np.load("/content/drive/MyDrive/project/y_test.npy")
person_train_valid = np.load("/content/drive/MyDrive/project/person_train_valid.npy")
X_train_valid = np.load("/content/drive/MyDrive/project/X_train_valid.npy")
y_train_valid = np.load("/content/drive/MyDrive/project/y_train_valid.npy")
person_test = np.load("/content/drive/MyDrive/project/person_test.npy")

## Adjusting the labels so that 

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769


## Random splitting and reshaping the data
# First generating the training and validation indices using random splitting

ind_valid = np.random.choice(2115, 375, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(X_train, X_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]


## Preprocessing the dataset
x_train,y_train = data_prep(X_train,y_train,2,2,True)
x_valid,y_valid = data_prep(X_valid,y_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)

# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
# print('Shape of training labels after categorical conversion:',y_train.shape)
# print('Shape of validation labels after categorical conversion:',y_valid.shape)
# print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
# print('Shape of training set after adding width info:',x_train.shape)
# print('Shape of validation set after adding width info:',x_valid.shape)
# print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
# print('Shape of training set after dimension reshaping:',x_train.shape)
# print('Shape of validation set after dimension reshaping:',x_valid.shape)
# print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of X after subsampling and concatenating: (6960, 22, 250)
# Shape of X after subsampling and concatenating: (1500, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)

# %%
# Building the CNN model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=16, kernel_size=(9,1), padding='same', activation='elu', input_shape=(250,1,22)))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=32, kernel_size=(9,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=32, kernel_size=(9,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))


# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model.add(Dense((32))) # FC layer with 100 units
hybrid_cnn_lstm_model.add(Reshape((32,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model.add(LSTM(32, dropout=0.5, recurrent_dropout=0.1, return_sequences=False))


# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 250, 1, 16)        3184
#
#  max_pooling2d (MaxPooling2D  (None, 84, 1, 16)        0
#  )
#
#  batch_normalization (BatchN  (None, 84, 1, 16)        64
#  ormalization)
#
#  dropout (Dropout)           (None, 84, 1, 16)         0
#
#  conv2d_1 (Conv2D)           (None, 84, 1, 32)         4640
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 1, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 28, 1, 32)        128
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 28, 1, 32)         0
#
#  conv2d_2 (Conv2D)           (None, 28, 1, 32)         9248
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 10, 1, 32)        128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 10, 1, 32)         0
#
#  flatten (Flatten)           (None, 320)               0
#
#  dense (Dense)               (None, 32)                10272
#
#  reshape (Reshape)           (None, 32, 1)             0
#
#  lstm (LSTM)                 (None, 32)                4352
#
#  dense_1 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 32,148
# Trainable params: 31,988
# Non-trainable params: 160
# _________________________________________________________________

# %%
# Model parameters
learning_rate = 0.001
epochs = 100
hybrid_cnn_lstm_optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

# %%
# Compiling the model
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_lstm_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=64,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/100
# 2023-03-19 23:30:51.341212: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 109/109 [==============================] - 4s 27ms/step - loss: 1.3698 - accuracy: 0.3023 - val_loss: 1.3297 - val_accuracy: 0.3580
# Epoch 2/100
# 109/109 [==============================] - 3s 25ms/step - loss: 1.2847 - accuracy: 0.3876 - val_loss: 1.2329 - val_accuracy: 0.4387
# Epoch 3/100
# 109/109 [==============================] - 3s 24ms/step - loss: 1.2217 - accuracy: 0.4315 - val_loss: 1.2034 - val_accuracy: 0.4660
# Epoch 4/100
# 109/109 [==============================] - 3s 24ms/step - loss: 1.1755 - accuracy: 0.4635 - val_loss: 1.1979 - val_accuracy: 0.4620
# Epoch 5/100
# 109/109 [==============================] - 3s 24ms/step - loss: 1.1522 - accuracy: 0.4773 - val_loss: 1.1541 - val_accuracy: 0.4647
# Epoch 6/100
# 109/109 [==============================] - 3s 26ms/step - loss: 1.1208 - accuracy: 0.5009 - val_loss: 1.1464 - val_accuracy: 0.4960
# Epoch 7/100
# 109/109 [==============================] - 3s 25ms/step - loss: 1.1009 - accuracy: 0.5125 - val_loss: 1.1580 - val_accuracy: 0.4773
# Epoch 8/100
# 109/109 [==============================] - 3s 24ms/step - loss: 1.0858 - accuracy: 0.5197 - val_loss: 1.1411 - val_accuracy: 0.5120
# Epoch 9/100
# 109/109 [==============================] - 3s 24ms/step - loss: 1.0661 - accuracy: 0.5352 - val_loss: 1.1179 - val_accuracy: 0.5193
# Epoch 10/100
# 109/109 [==============================] - 3s 25ms/step - loss: 1.0467 - accuracy: 0.5487 - val_loss: 1.1427 - val_accuracy: 0.5053
# Epoch 11/100
# 109/109 [==============================] - 3s 25ms/step - loss: 1.0233 - accuracy: 0.5685 - val_loss: 1.1119 - val_accuracy: 0.5307
# Epoch 12/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.9977 - accuracy: 0.5783 - val_loss: 1.1210 - val_accuracy: 0.5233
# Epoch 13/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.9836 - accuracy: 0.5878 - val_loss: 1.1065 - val_accuracy: 0.5387
# Epoch 14/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.9676 - accuracy: 0.5989 - val_loss: 1.0526 - val_accuracy: 0.5520
# Epoch 15/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.9418 - accuracy: 0.6204 - val_loss: 1.0347 - val_accuracy: 0.5840
# Epoch 16/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.9469 - accuracy: 0.6114 - val_loss: 1.0132 - val_accuracy: 0.5927
# Epoch 17/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.9384 - accuracy: 0.6180 - val_loss: 1.0478 - val_accuracy: 0.5627
# Epoch 18/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.9136 - accuracy: 0.6333 - val_loss: 0.9736 - val_accuracy: 0.5980
# Epoch 19/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.8915 - accuracy: 0.6480 - val_loss: 0.9819 - val_accuracy: 0.6120
# Epoch 20/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.8810 - accuracy: 0.6455 - val_loss: 0.9621 - val_accuracy: 0.6153
# Epoch 21/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.8736 - accuracy: 0.6572 - val_loss: 0.9189 - val_accuracy: 0.6153
# Epoch 22/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.8487 - accuracy: 0.6684 - val_loss: 0.9289 - val_accuracy: 0.6120
# Epoch 23/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.8495 - accuracy: 0.6649 - val_loss: 0.9412 - val_accuracy: 0.6120
# Epoch 24/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.8298 - accuracy: 0.6749 - val_loss: 0.8857 - val_accuracy: 0.6347
# Epoch 25/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.8254 - accuracy: 0.6760 - val_loss: 0.8722 - val_accuracy: 0.6607
# Epoch 26/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.8182 - accuracy: 0.6766 - val_loss: 0.8524 - val_accuracy: 0.6773
# Epoch 27/100
# 109/109 [==============================] - 3s 28ms/step - loss: 0.8106 - accuracy: 0.6807 - val_loss: 0.8768 - val_accuracy: 0.6573
# Epoch 28/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.7971 - accuracy: 0.6907 - val_loss: 0.8698 - val_accuracy: 0.6720
# Epoch 29/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.7868 - accuracy: 0.6930 - val_loss: 0.8425 - val_accuracy: 0.6687
# Epoch 30/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.7644 - accuracy: 0.7034 - val_loss: 0.8619 - val_accuracy: 0.6547
# Epoch 31/100
# 109/109 [==============================] - 3s 27ms/step - loss: 0.7717 - accuracy: 0.6994 - val_loss: 0.8738 - val_accuracy: 0.6367
# Epoch 32/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7714 - accuracy: 0.6996 - val_loss: 0.8639 - val_accuracy: 0.6520
# Epoch 33/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7611 - accuracy: 0.7037 - val_loss: 0.8175 - val_accuracy: 0.6687
# Epoch 34/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7559 - accuracy: 0.7045 - val_loss: 0.8680 - val_accuracy: 0.6433
# Epoch 35/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7552 - accuracy: 0.7108 - val_loss: 0.8271 - val_accuracy: 0.6680
# Epoch 36/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7306 - accuracy: 0.7223 - val_loss: 0.8666 - val_accuracy: 0.6547
# Epoch 37/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7402 - accuracy: 0.7136 - val_loss: 0.8480 - val_accuracy: 0.6613
# Epoch 38/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7329 - accuracy: 0.7174 - val_loss: 0.8358 - val_accuracy: 0.6733
# Epoch 39/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7286 - accuracy: 0.7155 - val_loss: 0.8233 - val_accuracy: 0.6773
# Epoch 40/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7127 - accuracy: 0.7254 - val_loss: 0.8337 - val_accuracy: 0.6707
# Epoch 41/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7363 - accuracy: 0.7154 - val_loss: 0.7865 - val_accuracy: 0.6880
# Epoch 42/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7178 - accuracy: 0.7259 - val_loss: 0.8871 - val_accuracy: 0.6520
# Epoch 43/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7067 - accuracy: 0.7284 - val_loss: 0.7779 - val_accuracy: 0.6987
# Epoch 44/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7194 - accuracy: 0.7250 - val_loss: 0.7838 - val_accuracy: 0.6987
# Epoch 45/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.7022 - accuracy: 0.7333 - val_loss: 0.7444 - val_accuracy: 0.7067
# Epoch 46/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6990 - accuracy: 0.7309 - val_loss: 0.7946 - val_accuracy: 0.6987
# Epoch 47/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6884 - accuracy: 0.7333 - val_loss: 0.8187 - val_accuracy: 0.6987
# Epoch 48/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6805 - accuracy: 0.7428 - val_loss: 0.7772 - val_accuracy: 0.7013
# Epoch 49/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6910 - accuracy: 0.7374 - val_loss: 0.8273 - val_accuracy: 0.6713
# Epoch 50/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6846 - accuracy: 0.7307 - val_loss: 0.8290 - val_accuracy: 0.6940
# Epoch 51/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6764 - accuracy: 0.7404 - val_loss: 0.7928 - val_accuracy: 0.6927
# Epoch 52/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6732 - accuracy: 0.7430 - val_loss: 0.7973 - val_accuracy: 0.6947
# Epoch 53/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6745 - accuracy: 0.7379 - val_loss: 0.8003 - val_accuracy: 0.6887
# Epoch 54/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6816 - accuracy: 0.7369 - val_loss: 0.7609 - val_accuracy: 0.7147
# Epoch 55/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6650 - accuracy: 0.7422 - val_loss: 0.7733 - val_accuracy: 0.7020
# Epoch 56/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6609 - accuracy: 0.7427 - val_loss: 0.7951 - val_accuracy: 0.7040
# Epoch 57/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6619 - accuracy: 0.7411 - val_loss: 0.7720 - val_accuracy: 0.7033
# Epoch 58/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6487 - accuracy: 0.7491 - val_loss: 0.7816 - val_accuracy: 0.7093
# Epoch 59/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6463 - accuracy: 0.7533 - val_loss: 0.8019 - val_accuracy: 0.7040
# Epoch 60/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6580 - accuracy: 0.7513 - val_loss: 0.7723 - val_accuracy: 0.7047
# Epoch 61/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6568 - accuracy: 0.7477 - val_loss: 0.7907 - val_accuracy: 0.6873
# Epoch 62/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6430 - accuracy: 0.7611 - val_loss: 0.7948 - val_accuracy: 0.7073
# Epoch 63/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.6611 - accuracy: 0.7437 - val_loss: 0.7856 - val_accuracy: 0.6853
# Epoch 64/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.6370 - accuracy: 0.7560 - val_loss: 0.7826 - val_accuracy: 0.6940
# Epoch 65/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.6497 - accuracy: 0.7480 - val_loss: 0.8048 - val_accuracy: 0.6873
# Epoch 66/100
# 109/109 [==============================] - 3s 26ms/step - loss: 0.6362 - accuracy: 0.7572 - val_loss: 0.7610 - val_accuracy: 0.7020
# Epoch 67/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6304 - accuracy: 0.7569 - val_loss: 0.7769 - val_accuracy: 0.7053
# Epoch 68/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6189 - accuracy: 0.7632 - val_loss: 0.7869 - val_accuracy: 0.7107
# Epoch 69/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6341 - accuracy: 0.7586 - val_loss: 0.7827 - val_accuracy: 0.6960
# Epoch 70/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6151 - accuracy: 0.7694 - val_loss: 0.7908 - val_accuracy: 0.7040
# Epoch 71/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6217 - accuracy: 0.7641 - val_loss: 0.7616 - val_accuracy: 0.6967
# Epoch 72/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6263 - accuracy: 0.7609 - val_loss: 0.8033 - val_accuracy: 0.6873
# Epoch 73/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6194 - accuracy: 0.7606 - val_loss: 0.7873 - val_accuracy: 0.6940
# Epoch 74/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6372 - accuracy: 0.7550 - val_loss: 0.7357 - val_accuracy: 0.7213
# Epoch 75/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6194 - accuracy: 0.7634 - val_loss: 0.7284 - val_accuracy: 0.7113
# Epoch 76/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6182 - accuracy: 0.7638 - val_loss: 0.7624 - val_accuracy: 0.6887
# Epoch 77/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6035 - accuracy: 0.7723 - val_loss: 0.7697 - val_accuracy: 0.6973
# Epoch 78/100
# 109/109 [==============================] - 3s 23ms/step - loss: 0.6190 - accuracy: 0.7582 - val_loss: 0.7259 - val_accuracy: 0.7220
# Epoch 79/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6228 - accuracy: 0.7622 - val_loss: 0.7288 - val_accuracy: 0.7233
# Epoch 80/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6093 - accuracy: 0.7677 - val_loss: 0.7399 - val_accuracy: 0.7087
# Epoch 81/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6230 - accuracy: 0.7634 - val_loss: 0.7610 - val_accuracy: 0.7067
# Epoch 82/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6013 - accuracy: 0.7708 - val_loss: 0.7121 - val_accuracy: 0.7227
# Epoch 83/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5986 - accuracy: 0.7744 - val_loss: 0.7727 - val_accuracy: 0.7020
# Epoch 84/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6099 - accuracy: 0.7695 - val_loss: 0.7218 - val_accuracy: 0.7227
# Epoch 85/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6001 - accuracy: 0.7746 - val_loss: 0.7504 - val_accuracy: 0.7247
# Epoch 86/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6249 - accuracy: 0.7573 - val_loss: 0.7728 - val_accuracy: 0.7040
# Epoch 87/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6037 - accuracy: 0.7731 - val_loss: 0.7709 - val_accuracy: 0.7053
# Epoch 88/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6078 - accuracy: 0.7671 - val_loss: 0.7438 - val_accuracy: 0.7240
# Epoch 89/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5844 - accuracy: 0.7796 - val_loss: 0.7247 - val_accuracy: 0.7307
# Epoch 90/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5965 - accuracy: 0.7746 - val_loss: 0.7751 - val_accuracy: 0.7087
# Epoch 91/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5888 - accuracy: 0.7746 - val_loss: 0.7765 - val_accuracy: 0.7040
# Epoch 92/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6046 - accuracy: 0.7688 - val_loss: 0.7391 - val_accuracy: 0.7133
# Epoch 93/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.6011 - accuracy: 0.7695 - val_loss: 0.7308 - val_accuracy: 0.7067
# Epoch 94/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5975 - accuracy: 0.7713 - val_loss: 0.7772 - val_accuracy: 0.7120
# Epoch 95/100
# 109/109 [==============================] - 3s 25ms/step - loss: 0.5787 - accuracy: 0.7799 - val_loss: 0.7353 - val_accuracy: 0.7140
# Epoch 96/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5953 - accuracy: 0.7736 - val_loss: 0.7782 - val_accuracy: 0.7027
# Epoch 97/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5808 - accuracy: 0.7776 - val_loss: 0.7706 - val_accuracy: 0.7100
# Epoch 98/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5805 - accuracy: 0.7809 - val_loss: 0.8025 - val_accuracy: 0.6953
# Epoch 99/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5723 - accuracy: 0.7829 - val_loss: 0.7859 - val_accuracy: 0.7060
# Epoch 100/100
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5768 - accuracy: 0.7774 - val_loss: 0.7604 - val_accuracy: 0.7060

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-LSTM model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-LSTM model: 0.7200902700424194

# %%
# Plotting accuracy trajectory
plt.figure()
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-LSTM model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('acc.png')

# Plotting loss trajectory
plt.figure()
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-LSTM model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('loss.png')

# %%
hybrid_cnn_lstm_model.save('../best_cnnlstm.h5')
